# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import pandas as pd
import numpy as np

# %%
# Loading the dataset
df_loaded = pd.read_csv('/content/module_159_data.csv')
df_loaded.head()
# Out:
#      step_0    step_1    step_2    step_3    step_4    step_5    step_6  \
# 0  0.891606  0.005835  0.902900  0.370187  0.156339  0.472637  0.431836
# 1  0.844764  0.780533  0.411477  0.078435  0.852747  0.542090  0.107046
# 2  0.850518  0.787294  0.365670  0.089276  0.064969  0.713258  0.931587
# 3  0.698502  0.680091  0.543954  0.685820  0.424197  0.839638  0.691607
# 4  0.628251  0.717192  0.233884  0.596176  0.339106  0.695727  0.729802
#
#      step_7    step_8    step_9  target
# 0  0.770866  0.119194  0.188136       0
# 1  0.610290  0.918214  0.258306       1
# 2  0.770217  0.291395  0.885698       1
# 3  0.389333  0.168020  0.282097       1
# 4  0.470927  0.409624  0.884498       1
